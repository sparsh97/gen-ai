# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_community.tools import tool
load_dotenv()
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_11244\193490585.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper
# True

# %%
from langchain.agents import create_agent

llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash")
search = GoogleSerperAPIWrapper()


agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="you are a agent and can search any question on web or google"
)

# %%
question = "where is madhav kunj pg exist in noida"

# %%
response = agent.invoke({"messages": [{"role": "user", "content": question}]})
print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'In Noida, **Madhav Kunj** (which is a popular residential locality hosting several PG and studio apartment accommodations) is located in **Sector 128**. \n\nThe exact location details are as follows:\n\n* **Locality/Area:** Shahpur Govardhanpur Bangar (also known as Sahaour Goberdhanpur), Sector 128, Noida, Uttar Pradesh - 201304.\n* **Landmark:** Very close to the **Max Super Speciality Hospital** (Sector 128).\n* **Specific Address Indicators:** Often located around Gali Number 56, Shahpur, Sector 128. \n\n*(Note: There are also other similarly named "Madhav PGs" in Noida, such as one in **Sector 63** near H-Block/H220 and another in **Sector 108**, but the specific area known as **Madhav Kunj** is situated in Sector 128 near the Max Hospital).*', 'extras': {'signature': '...'}}]
