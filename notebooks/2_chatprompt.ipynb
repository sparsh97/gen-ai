# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatMessagePromptTemplate
from langchain_core.output_parsers import StrOutputParser


llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash")

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an {language} developer."),
    ("user", "{query}")
])
strParser = StrOutputParser()
final_prompt = prompt | llm | strParser

# %%
res = final_prompt.invoke({"language": "python", "query": "why python used in AI"})
print(res)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Python has become the *de facto* standard language for Artificial Intelligence (AI), Machine Learning (ML), and Deep Learning.
#
# Here is a detailed breakdown of why Python dominates the AI landscape:
#
# ---
#
# ### 1. Simplicity and Readability
# AI algorithms are mathematically complex. Python’s syntax is clean, intuitive, and closely resembles everyday English.
# * **Focus on the Problem:** Because Python requires fewer lines of code than languages like C++ or Java, developers can focus on solving AI problems rather than fighting the syntax of the language.
# * **Easy to Learn:** This low entry barrier allows mathematicians, data scientists, and physicists to write AI code without needing a formal computer science degree.
#
# ### 2. An Unmatched Ecosystem of Libraries
# In AI, you rarely write algorithms from scratch. Python has the richest ecosystem of pre-built libraries and frameworks, which act as Lego blocks for AI development:
# * **Machine Learning:** `Scikit-learn` (for classic ML algorithms like regression and clustering).
# * **Deep Learning & Neural Networks:** `TensorFlow` (developed by Google) and `PyTorch` (developed by Meta).
# * **Data Manipulation:** `Pandas` (for data analysis) and `NumPy` (for high-performance scientific computing and multi-dimensional arrays).
# * **Natural Language Processing (NLP):** `NLTK`, `SpaCy`, and Hugging Face's `Transformers`.
# * **Data Visualization:** `Matplotlib` and `Seaborn` (for turning data into charts and graphs).
#
# ### 3. Python as a "Glue" Language (Performance + Ease)
# A common criticism of Python is that it is slow compared to C++ or Julia. However, Python solves this by acting as a **"glue language."**
# * The core of major AI libraries (like TensorFlow and NumPy) is actually written in **C or C++** for maximum speed and GPU acceleration.
# * Python is used as a user-friendly "wrapper" or interface on top of this fast C/C++ code. This gives developers the **speed of C++ with the ease of Python**.
#
# ### 4. Platform Independence
# AI models need to be trained on powerful machines (often in the cloud) but deployed on various devices (servers, PCs, mobile, or edge devices).
# * Python is platform-independent. Code written on a Mac can easily run on Windows, Linux, or specialized AI cloud hardware (like Google’s TPUs or NVIDIA’s GPUs).
#
# ### 5. Strong Community and Corporate Backing
# Python has a massive, active global community.
# * **Support:** If you run into a bug or a complex AI math problem, chances are someone has already solved it on Stack Overflow or GitHub.
# * **Corporate Support:** Tech giants like Google, Meta, Microsoft, and Netflix heavily invest in Python’s AI ecosystem, ensuring the tools are continuously updated, optimized, and documented.
#
# ### 6. Excellent Data Visualization
# AI is highly dependent on data. To understand data, you must visualize it. Python offers sophisticated APIs for visualization, allowing AI engineers to build interactive plots, heatmaps, and charts easily.
#
# ---
#
# ### Summary Comparison: Python vs. Other Languages
#
# | Feature | Python | C++ | R | Java |
# | :--- | :--- | :--- | :--- | :--- |
# | **Learning Curve** | Very Easy | Hard | Medium | Medium |
# | **AI Libraries** | Exceptional | Moderate | Good (mainly stats) | Moderate |
# | **Execution Speed** | Slow (but fast via C-wrappers) | Extremely Fast | Slow | Fast |
# | **Use Case in AI** | **Prototyping & Production** | **Hardware Optimization** | **Statistical Analysis** | **Enterprise Integration** |
#
# ### Conclusion
# While other languages have their niche (C++ for high-performance game AI/robotics, R for statistics), **Python is the undisputed king of general AI development**. It successfully bridges the gap between scientific research and commercial software development.
