# %%
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader
load_dotenv()
# Out:
# C:\Users\Sparsh\AppData\Local\Temp\ipykernel_11220\1087280980.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# True

# %%
loader = TextLoader("../data/Install_UWP.txt")

# %%
doc = loader.load()
# Out:
# [Document(metadata={'source': '../data/Install_UWP.txt'}, page_content='\n@echo off\nSET OSDST=%~d0\nif not exist %~d0\\OEM\\Preload\\Command\\POP*.ini set OSDST=C:\nif not exist %OSDST%\\OEM\\AcerLogs md %OSDST%\\OEM\\AcerLogs\nSET LogPath=%OSDST%\\OEM\\AcerLogs\\DriverInstallation.Log\nECHO.>>%LogPath%\nECHO %DATE% %TIME%[Log START]  ============ %~dpnx0 ============ >> %LogPath%\nSETLOCAL ENABLEDELAYEDEXPANSION\npushd "%~dp0"\n:::: clear %OSDST%\\OEM\\FilterVCLibsList.txt\nif exist %OSDST%\\OEM\\FilterVCLibsList.txt del /f /q %OSDST%\\OEM\\FilterVCLibsList.txt >NUL 2>&1\nif exist CheckingVCLib2_Done.tag del /f /q CheckingVCLib2_Done.tag >NUL 2>&1\nmd "%temp%\\scratchdir"\nSET TargetVCLib=Microsoft.VCLibs.140.00_\nECHO %DATE% %TIME%[Log TRACE]  SET ImgPath=/online >>%LogPath% 2>&1\nSET ImgPath=/online\nECHO %DATE% %TIME%[Log TRACE]  reg query "HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows NT\\CurrentVersion\\WinPE" >>%LogPath% 2>&1\nreg query "HKEY_LOCAL_MACHINE\\Software\\Micro
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
